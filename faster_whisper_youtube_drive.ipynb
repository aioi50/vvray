# %% [markdown]
# <a href="https://colab.research.google.com/github/aioi50/vvray/blob/main/faster_whisper_youtube_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube/Google Drive Videos Translation/Transcription with Faster Whisper**
#
# [faster-whisper](https://github.com/guillaumekln/faster-whisper) is a reimplementation of OpenAI's Whisper model using CTranslate2, which is a fast inference engine for Transformer models.
#
# This implementation is up to 4 times faster than openai/whisper for the same accuracy while using less memory. The efficiency can be further improved with 8-bit quantization on both CPU and GPU.
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription or translation of a  video file (from Youtube/Google Drive) using Faster Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the output and video audio in your Google Drive.
#
# ## **How to use**
# 1. Read and understand the notebook. You should at the very least modify the **video selection section** to choose the video you wish to translate/transcribe
# 2. Click Runtime -> Run all and wait for the notebook to do its magic, alternatively you may run the cells one by one and skip the Google Drive portion if you do not intend to use it
# 3. A download prompt should appear once subtitles is ready, or check the 'Files' tab on the left for the output

# %%
#@markdown # **[Optional]** Access data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
from pathlib import Path

drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Faster Whisper" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-9d63f2fc-98a7-61b3-b528-b04170b4853d)
# Mon Feb  3 16:36:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Faster Whisper.

#@markdown ---

! pip install faster-whisper
! pip install yt-dlp

import os
import sys
import warnings
from faster_whisper import WhisperModel
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo
import requests
from urllib.parse import urlsplit
from google.colab import files
from pathlib import Path

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)

# !sudo apt-get update
# !sudo apt install nvidia-cuda-toolkit
# Out:
# Collecting faster-whisper
#   Downloading faster_whisper-1.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Downloading ctranslate2-4.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.11/dist-packages (from faster-whisper) (0.27.1)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.11/dist-packages (from faster-whisper) (0.21.0)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting av>=11 (from faster-whisper)
#   Downloading av-14.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (1.26.4)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.11/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.12.2)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.1.24)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (4.25.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2024.12.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Downloading faster_whisper-1.1.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 62.3 MB/s eta 0:00:00
# Downloading av-14.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 28.0 MB/s eta 0:00:00
# Downloading ctranslate2-4.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 21.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 112.2 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.0 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, ctranslate2, av, coloredlogs, onnxruntime, faster-whisper
# Successfully installed av-14.1.0 coloredlogs-15.0.1 ctranslate2-4.5.0 faster-whisper-1.1.1 humanfriendly-10.0 onnxruntime-1.20.1
# Collecting yt-dlp
#   Downloading yt_dlp-2025.1.26-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 14.4 MB/s eta 0:00:00
# Downloading yt_dlp-2025.1.26-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 98.7 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.1.26
# Using device: cuda:0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,654 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,606 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,906 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,229 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,522 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,651 kB]
# Fetched 20.0 MB in 4s (4,662 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaccinj64-11.5 libatk-wrapper-java
#   libatk-wrapper-java-jni libbabeltrace1 libcub-dev libcublas11 libcublaslt11
#   libcudart11.0 libcufft10 libcufftw10 libcuinj64-11.5 libcupti-dev
#   libcupti-doc libcupti11.5 libcurand10 libcusolver11 libcusolvermg11
#   libcusparse11 libdebuginfod-common libdebuginfod1 libegl-dev libfontenc1
#   libgail-common libgail18 libgl-dev libgl1-mesa-dev libgles-dev libgles1
#   libglvnd-core-dev libglvnd-dev libglx-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libipt2 libnppc11 libnppial11 libnppicc11 libnppidei11
#   libnppif11 libnppig11 libnppim11 libnppist11 libnppisu11 libnppitc11
#   libnpps11 libnvblas11 libnvidia-compute-495 libnvidia-compute-510
#   libnvidia-compute-535 libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5
#   libnvrtc11.2 libnvtoolsext1 libnvvm4 libopengl-dev librsvg2-common
#   libsource-highlight-common libsource-highlight4v5 libthrust-dev libvdpau-dev
#   libxkbfile1 libxtst6 libxxf86dga1 node-html5shiv nvidia-cuda-dev
#   nvidia-cuda-gdb nvidia-cuda-toolkit-doc nvidia-profiler
#   nvidia-visual-profiler openjdk-8-jre openjdk-8-jre-headless x11-utils
# Suggested packages:
#   gvfs libvdpau-doc nodejs libnss-mdns fonts-nanum fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei fonts-wqy-zenhei fonts-indic
#   mesa-utils
# Recommended packages:
#   libnvcuvid1 nsight-compute nsight-systems
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaccinj64-11.5 libatk-wrapper-java
#   libatk-wrapper-java-jni libbabeltrace1 libcub-dev libcublas11 libcublaslt11
#   libcudart11.0 libcufft10 libcufftw10 libcuinj64-11.5 libcupti-dev
#   libcupti-doc libcupti11.5 libcurand10 libcusolver11 libcusolvermg11
#   libcusparse11 libdebuginfod-common libdebuginfod1 libegl-dev libfontenc1
#   libgail-common libgail18 libgl-dev libgl1-mesa-dev libgles-dev libgles1
#   libglvnd-core-dev libglvnd-dev libglx-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libipt2 libnppc11 libnppial11 libnppicc11 libnppidei11
#   libnppif11 libnppig11 libnppim11 libnppist11 libnppisu11 libnppitc11
#   libnpps11 libnvblas11 libnvidia-compute-495 libnvidia-compute-510
#   libnvidia-compute-535 libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5
#   libnvrtc11.2 libnvtoolsext1 libnvvm4 libopengl-dev librsvg2-common
#   libsource-highlight-common libsource-highlight4v5 libthrust-dev libvdpau-dev
#   libxkbfile1 libxtst6 libxxf86dga1 node-html5shiv nvidia-cuda-dev
#   nvidia-cuda-gdb nvidia-cuda-toolkit nvidia-cuda-toolkit-doc nvidia-profiler
#   nvidia-visual-profiler openjdk-8-jre openjdk-8-jre-headless x11-utils
# 0 upgraded, 77 newly installed, 0 to remove and 20 not upgraded.
# Need to get 1,540 MB of archives.
# After this operation, 4,234 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-535 535.230.02-0ubuntu1 [36.9 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdebuginfod-common all 0.186-1build1 [7,878 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti11.5 amd64 11.5.114~11.5.1-1ubuntu1 [7,696 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libaccinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [845 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcub-dev all 1.15.0-3 [217 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublaslt11 amd64 11.7.4.6~11.5.1-1ubuntu1 [148 MB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [78.2 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcudart11.0 amd64 11.5.117~11.5.1-1ubuntu1 [178 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufft10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [70.4 MB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufftw10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [211 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-510 amd64 525.147.05-0ubuntu2.22.04.1 [7,310 B]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-495 amd64 510.108.03-0ubuntu0.22.04.1 [7,378 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcuinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [1,004 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcurand10 amd64 11.1.1+~10.2.7.107~11.5.1-1ubuntu1 [41.8 MB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolver11 amd64 11.3.2.107~11.5.1-1ubuntu1 [31.3 MB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolvermg11 amd64 11.3.2.107~11.5.1-1ubuntu1 [17.8 MB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusparse11 amd64 11.7.0.107~11.5.1-1ubuntu1 [96.2 MB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdebuginfod1 amd64 0.186-1build1 [12.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libipt2 amd64 2.0.5-1 [46.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [430 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppial11 amd64 11.5.1.107~11.5.1-1ubuntu1 [5,234 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppicc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,373 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppidei11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,587 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppif11 amd64 11.5.1.107~11.5.1-1ubuntu1 [33.8 MB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppig11 amd64 11.5.1.107~11.5.1-1ubuntu1 [14.5 MB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppim11 amd64 11.5.1.107~11.5.1-1ubuntu1 [3,037 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppist11 amd64 11.5.1.107~11.5.1-1ubuntu1 [13.7 MB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppisu11 amd64 11.5.1.107~11.5.1-1ubuntu1 [177 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppitc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [1,292 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnpps11 amd64 11.5.1.107~11.5.1-1ubuntu1 [7,116 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvblas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [191 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvidia-ml-dev amd64 11.5.50~11.5.1-1ubuntu1 [69.1 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvjpeg11 amd64 11.5.4.107~11.5.1-1ubuntu1 [1,858 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc-builtins11.5 amd64 11.5.119~11.5.1-1ubuntu1 [116 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc11.2 amd64 11.5.119~11.5.1-1ubuntu1 [15.7 MB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvvm4 amd64 11.5.119~11.5.1-1ubuntu1 [8,675 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:57 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight-common all 3.1.9-4.1build2 [64.5 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight4v5 amd64 3.1.9-4.1build2 [207 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvdpau-dev amd64 1.4-3build2 [38.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 node-html5shiv all 3.7.3+dfsg-4 [13.6 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-toolkit-doc all 11.5.1-1ubuntu1 [6,263 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-8-jre-headless amd64 8u432-ga~us1-0ubuntu2~22.04 [30.8 MB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-8-jre amd64 8u432-ga~us1-0ubuntu2~22.04 [75.3 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libbabeltrace1 amd64 1.5.8-2build1 [160 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti-dev amd64 11.5.114~11.5.1-1ubuntu1 [7,915 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti-doc all 11.5.114~11.5.1-1ubuntu1 [2,373 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvtoolsext1 amd64 11.5.114~11.5.1-1ubuntu1 [28.8 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libthrust-dev all 1.15.0-1 [423 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-dev amd64 11.5.1-1ubuntu1 [667 MB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-gdb amd64 11.5.114~11.5.1-1ubuntu1 [3,404 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-profiler amd64 11.5.114~11.5.1-1ubuntu1 [1,732 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-toolkit amd64 11.5.1-1ubuntu1 [62.8 MB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-visual-profiler amd64 11.5.114~11.5.1-1ubuntu1 [108 MB]
# Fetched 1,540 MB in 1min 12s (21.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 77.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libdebuginfod-common.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../00-libdebuginfod-common_0.186-1build1_all.deb ...
# Unpacking libdebuginfod-common (0.186-1build1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../01-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../02-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libcupti11.5:amd64.
# Preparing to unpack .../03-libcupti11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libaccinj64-11.5:amd64.
# Preparing to unpack .../04-libaccinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../05-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../06-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../07-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../08-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../09-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../10-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../11-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libcub-dev.
# Preparing to unpack .../12-libcub-dev_1.15.0-3_all.deb ...
# Unpacking libcub-dev (1.15.0-3) ...
# Selecting previously unselected package libcublaslt11:amd64.
# Preparing to unpack .../13-libcublaslt11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcublas11:amd64.
# Preparing to unpack .../14-libcublas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcudart11.0:amd64.
# Preparing to unpack .../15-libcudart11.0_11.5.117~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufft10:amd64.
# Preparing to unpack .../16-libcufft10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufftw10:amd64.
# Preparing to unpack .../17-libcufftw10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-535:amd64.
# Preparing to unpack .../18-libnvidia-compute-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-510:amd64.
# Preparing to unpack .../19-libnvidia-compute-510_525.147.05-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Selecting previously unselected package libnvidia-compute-495:amd64.
# Preparing to unpack .../20-libnvidia-compute-495_510.108.03-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcuinj64-11.5:amd64.
# Preparing to unpack .../21-libcuinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcurand10:amd64.
# Preparing to unpack .../22-libcurand10_11.1.1+~10.2.7.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolver11:amd64.
# Preparing to unpack .../23-libcusolver11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolvermg11:amd64.
# Preparing to unpack .../24-libcusolvermg11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusparse11:amd64.
# Preparing to unpack .../25-libcusparse11_11.7.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libdebuginfod1:amd64.
# Preparing to unpack .../26-libdebuginfod1_0.186-1build1_amd64.deb ...
# Unpacking libdebuginfod1:amd64 (0.186-1build1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../27-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../28-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../29-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../30-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../31-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../32-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../33-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../34-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../35-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../36-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libipt2.
# Preparing to unpack .../37-libipt2_2.0.5-1_amd64.deb ...
# Unpacking libipt2 (2.0.5-1) ...
# Selecting previously unselected package libnppc11:amd64.
# Preparing to unpack .../38-libnppc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppial11:amd64.
# Preparing to unpack .../39-libnppial11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppicc11:amd64.
# Preparing to unpack .../40-libnppicc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppidei11:amd64.
# Preparing to unpack .../41-libnppidei11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppif11:amd64.
# Preparing to unpack .../42-libnppif11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppig11:amd64.
# Preparing to unpack .../43-libnppig11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppim11:amd64.
# Preparing to unpack .../44-libnppim11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppist11:amd64.
# Preparing to unpack .../45-libnppist11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppisu11:amd64.
# Preparing to unpack .../46-libnppisu11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppitc11:amd64.
# Preparing to unpack .../47-libnppitc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnpps11:amd64.
# Preparing to unpack .../48-libnpps11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvblas11:amd64.
# Preparing to unpack .../49-libnvblas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-ml-dev:amd64.
# Preparing to unpack .../50-libnvidia-ml-dev_11.5.50~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvjpeg11:amd64.
# Preparing to unpack .../51-libnvjpeg11_11.5.4.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc-builtins11.5:amd64.
# Preparing to unpack .../52-libnvrtc-builtins11.5_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc11.2:amd64.
# Preparing to unpack .../53-libnvrtc11.2_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvvm4:amd64.
# Preparing to unpack .../54-libnvvm4_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../55-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../56-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libsource-highlight-common.
# Preparing to unpack .../57-libsource-highlight-common_3.1.9-4.1build2_all.deb ...
# Unpacking libsource-highlight-common (3.1.9-4.1build2) ...
# Selecting previously unselected package libsource-highlight4v5.
# Preparing to unpack .../58-libsource-highlight4v5_3.1.9-4.1build2_amd64.deb ...
# Unpacking libsource-highlight4v5 (3.1.9-4.1build2) ...
# Selecting previously unselected package libvdpau-dev:amd64.
# Preparing to unpack .../59-libvdpau-dev_1.4-3build2_amd64.deb ...
# Unpacking libvdpau-dev:amd64 (1.4-3build2) ...
# Selecting previously unselected package node-html5shiv.
# Preparing to unpack .../60-node-html5shiv_3.7.3+dfsg-4_all.deb ...
# Unpacking node-html5shiv (3.7.3+dfsg-4) ...
# Selecting previously unselected package nvidia-cuda-toolkit-doc.
# Preparing to unpack .../61-nvidia-cuda-toolkit-doc_11.5.1-1ubuntu1_all.deb ...
# Unpacking nvidia-cuda-toolkit-doc (11.5.1-1ubuntu1) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../62-openjdk-8-jre-headless_8u432-ga~us1-0ubuntu2~22.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u432-ga~us1-0ubuntu2~22.04) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../63-openjdk-8-jre_8u432-ga~us1-0ubuntu2~22.04_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u432-ga~us1-0ubuntu2~22.04) ...
# Selecting previously unselected package libbabeltrace1:amd64.
# Preparing to unpack .../64-libbabeltrace1_1.5.8-2build1_amd64.deb ...
# Unpacking libbabeltrace1:amd64 (1.5.8-2build1) ...
# Selecting previously unselected package libcupti-dev:amd64.
# Preparing to unpack .../65-libcupti-dev_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcupti-doc.
# Preparing to unpack .../66-libcupti-doc_11.5.114~11.5.1-1ubuntu1_all.deb ...
# Unpacking libcupti-doc (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../67-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../68-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../69-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libnvtoolsext1:amd64.
# Preparing to unpack .../70-libnvtoolsext1_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libthrust-dev.
# Preparing to unpack .../71-libthrust-dev_1.15.0-1_all.deb ...
# Unpacking libthrust-dev (1.15.0-1) ...
# Selecting previously unselected package nvidia-cuda-dev:amd64.
# Preparing to unpack .../72-nvidia-cuda-dev_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-gdb.
# Preparing to unpack .../73-nvidia-cuda-gdb_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-gdb (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-profiler.
# Preparing to unpack .../74-nvidia-profiler_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-toolkit.
# Preparing to unpack .../75-nvidia-cuda-toolkit_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-visual-profiler.
# Preparing to unpack .../76-nvidia-visual-profiler_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-visual-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libdebuginfod-common (0.186-1build1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/profile.d/debuginfod.sh with new version
#
# Creating config file /etc/profile.d/debuginfod.csh with new version
# Setting up libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libdebuginfod1:amd64 (0.186-1build1) ...
# Setting up node-html5shiv (3.7.3+dfsg-4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libcupti-doc (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libsource-highlight-common (3.1.9-4.1build2) ...
# Setting up libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Setting up libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u432-ga~us1-0ubuntu2~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up libipt2 (2.0.5-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libbabeltrace1:amd64 (1.5.8-2build1) ...
# Setting up libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-compute-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libvdpau-dev:amd64 (1.4-3build2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libcub-dev (1.15.0-3) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up nvidia-cuda-toolkit-doc (11.5.1-1ubuntu1) ...
# Setting up libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Setting up libsource-highlight4v5 (3.1.9-4.1build2) ...
# Setting up libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libthrust-dev (1.15.0-1) ...
# Setting up libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-gdb (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Setting up libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Setting up libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up openjdk-8-jre:amd64 (8u432-ga~us1-0ubuntu2~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up nvidia-visual-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
#@markdown # **Model selection** 🧠

#@markdown There are several models to choose from, with varying performance and speed. large-v2 is recommended for most cases:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~0.8 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1.0 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~1.4 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~2.7 GB     |      ~2x       |
#@markdown | large-v1  |   1550 M   |        N/A         |      `large-v1`       |    ~4.3 GB     |       1x       |
#@markdown | large-v2  |   1550 M   |        N/A         |      `large-v2`       |    ~4.3 GB     |       1x       |

#@markdown ---
model_size = "large-v3" # @param ["tiny","tiny.en","base","base.en","small","small.en","medium","medium.en","large-v1","large-v3"]
device_type = "cuda" #@param {type:"string"} ['cuda', 'cpu']
compute_type = "float32" # @param ["float32","int8_float16","int8"]
#@markdown ---
#@markdown **Run this cell again if you change the model.**

model = WhisperModel(model_size, device=device_type, compute_type=compute_type)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# vocabulary.json:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.39k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video **OR** Google drive video path of the video you want to translate/transcribe, and run the cell. Make sure the correct Type is chosen! This may take awhile depending on video file size.

Type = "Google Drive" #@param ['Youtube video or playlist', 'Google Drive', 'Direct download']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=9ez8lm9I26Y" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "1/UPLD-002.mp4" #@param {type:"string"}
#@markdown ---
#@markdown #### **Direct Download**
ddl_url = "https://www.example.com/video.mkv" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for processing.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        print(f"{video_path_local} appended to list for processing")
        display(Markdown(f"**{str(video_path)} selected for processing.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

elif Type == "Direct download":
    print(f"⚠️ Please ensure this is a direct download link and is of a valid format")
    print(f"Attempting to download: {ddl_url}\n")
    # !wget {ddl_url} -O ddl_video.mp4
    # video_path_local_list.append("/content/ddl_video.mp4")

    response = requests.get(ddl_url)

    if response.status_code == 200:
        # Extract the filename from the URL
        filename = urlsplit(ddl_url).path.split("/")[-1]

        # Create the full path for the destination file in the current working directory
        destination_path = os.path.join(os.getcwd(), filename)

        # Save the file
        with open(destination_path, 'wb') as file:
            file.write(response.content)

        print(f"File downloaded successfully: {destination_path}")

        video_path_local = Path(".").resolve() / (filename)

        # print(f"Path local: {video_path_local}") # /content/video.mkv

        video_path_local_list.append(video_path_local)
    else:
        print(f"Failed to download file. Status code: {response.status_code}")

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    valid_suffixes = [".mp4", ".mkv", ".mov", ".avi", ".wmv", ".flv", ".webm", ".3gp", ".mpeg"]

    print(f"Processing video file {video_path_local} with ffmpeg..")

    if video_path_local.suffix in valid_suffixes:
        input_suffix = video_path_local.suffix
        video_path_local = video_path_local.with_suffix(".wav")
        result = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(input_suffix)), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# /content/UPLD-002.mp4 appended to list for processing
# **/content/drive/My Drive/1/UPLD-002.mp4 selected for processing.**
# Processing video file /content/UPLD-002.mp4 with ffmpeg..

# %%
def seconds_to_time_format(s):
    # Convert seconds to hours, minutes, seconds, and milliseconds
    hours = s // 3600
    s %= 3600
    minutes = s // 60
    s %= 60
    seconds = s // 1
    milliseconds = round((s % 1) * 1000)

    # Return the formatted string
    return f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d},{int(milliseconds):03d}"

#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription/translation of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown #### Language
language = "ja" #@param ["auto", "en", "zh", "ja", "fr", "de"] {allow-input: true}
#@markdown #### initial prompt (change to transcribe if you prefer transcribing only)
initial_prompt = "Please transcribe this from Japanese." #@param {type:"string"}
#@markdown ---
#@markdown #### Word-level timestamps
word_level_timestamps = False #@param {type:"boolean"}
#@markdown ---
#@markdown #### VAD filter
vad_filter = True #@param {type:"boolean"}
vad_filter_min_silence_duration_ms = 50 #@param {type:"integer"}
#@markdown ---
#@markdown #### Output (Default is srt, txt if `text_only` be checked )
text_only = False #@param {type:"boolean"}


segments, info = model.transcribe(str(video_path_local), beam_size=5,
                                  language=None if language == "auto" else language,
                                  initial_prompt=initial_prompt,
                                  word_timestamps=word_level_timestamps,
                                  vad_filter=vad_filter,
                                  vad_parameters=dict(min_silence_duration_ms=vad_filter_min_silence_duration_ms))

display(Markdown(f"Detected language '{info.language}' with probability {info.language_probability}"))

ext_name = '.txt' if text_only else ".srt"
output_file_name = video_path_local.stem + ext_name
sentence_idx = 1
with open(output_file_name, 'w') as f:
  for segment in segments:
    if word_level_timestamps:
      for word in segment.words:
        ts_start = seconds_to_time_format(word.start)
        ts_end = seconds_to_time_format(word.end)
        print(f"[{ts_start} --> {ts_end}] {word.word}")
        if not text_only:
          f.write(f"{sentence_idx}\n")
          f.write(f"{ts_start} --> {ts_end}\n")
          f.write(f"{word.word}\n\n")
        else:
          f.write(f"{word.word}")
        f.write("\n")
        sentence_idx = sentence_idx + 1
    else:
      ts_start = seconds_to_time_format(segment.start)
      ts_end = seconds_to_time_format(segment.end)
      print(f"[{ts_start} --> {ts_end}] {segment.text}")
      if not text_only:
        f.write(f"{sentence_idx}\n")
        f.write(f"{ts_start} --> {ts_end}\n")
        f.write(f"{segment.text.strip()}\n\n")
      else:
        f.write(f"{segment.text.strip()}\n")
      sentence_idx = sentence_idx + 1

try:
  files.download(output_file_name)
  shutil.copy(video_path_local.parent / output_file_name,
            drive_whisper_path / output_file_name
  )
  display(Markdown(f"**Output file created: {drive_whisper_path / output_file_name}**"))
except:
  display(Markdown(f"**Output file created: {video_path_local.parent / output_file_name}**"))
# Out:
# Detected language 'ja' with probability 1
# [00:00:01,230 --> 00:00:05,130] すごい
# [00:01:32,550 --> 00:01:34,550] 疲れた
# [00:01:34,550 --> 00:01:36,550] 広くないですか?
# [00:01:36,550 --> 00:01:38,550] どうぞ
# [00:01:41,970 --> 00:01:42,970] 疲れた
# [00:01:42,970 --> 00:01:44,970] 今日の飲み会最高だったね
# [00:01:44,970 --> 00:01:45,970] いいですね
# [00:01:45,970 --> 00:01:47,970] どうぞ座って座って
# [00:01:50,350 --> 00:01:55,930] どうしたの?
# [00:01:55,930 --> 00:01:57,930] いや、何もないです
# [00:01:57,930 --> 00:02:00,660] 絶対そうなんだけど
# [00:02:00,660 --> 00:02:01,660] 内緒よ
# [00:02:01,660 --> 00:02:03,730] 内緒なんだけど
# [00:02:03,730 --> 00:02:04,730] 受付の
# [00:02:04,730 --> 00:02:05,820] あの子いるじゃん
# [00:02:05,820 --> 00:02:06,820] 右側の子
# [00:02:06,820 --> 00:02:09,910] いつも右側にいる受付の子
# [00:02:09,910 --> 00:02:10,910] 目を見せたんですかね?
# [00:02:10,910 --> 00:02:14,130] 狙ってるよ
# [00:02:14,130 --> 00:02:15,130] 僕ですか?
# [00:02:15,130 --> 00:02:17,130] 私知ってるもん
# [00:02:17,130 --> 00:02:18,130] マジっすか?
# [00:02:18,130 --> 00:02:20,130] 裏で言ってたもん
# [00:02:20,130 --> 00:02:23,340] 女子トイレ怖いよ
# [00:02:23,340 --> 00:02:25,340] あんまそんな
# [00:02:25,340 --> 00:02:26,340] そんな素振りとか
# [00:02:26,340 --> 00:02:27,340] あんまなかったですけどね
# [00:02:27,340 --> 00:02:28,340] あと経理のおばちゃん
# [00:02:28,340 --> 00:02:31,340] このまま病床を切ってくれなかったおばちゃんが
# [00:02:31,340 --> 00:02:34,460] いいね
# [00:02:34,460 --> 00:02:35,460] って言ってた
# [00:02:35,460 --> 00:02:36,460] マジで
# [00:02:36,460 --> 00:02:37,460] 本当ですか?
# [00:02:38,460 --> 00:02:40,520] お尻のプリッケツがいいって言ってた
# [00:02:40,520 --> 00:02:42,900] あーでもなんかいつもなんか
# [00:02:42,900 --> 00:02:44,900] たまにあめくれるんですよ
# [00:02:44,900 --> 00:02:45,900] なんか
# [00:02:45,900 --> 00:02:46,900] 触られない?たまに
# [00:02:46,900 --> 00:02:48,900] この前触ったって言ってたよ
# [00:02:48,900 --> 00:02:51,900] いや、なんかね
# [00:02:51,900 --> 00:02:53,900] なんかね、こんな感じ
# [00:02:53,900 --> 00:02:54,900] こんな感じで
# [00:02:54,900 --> 00:02:55,900] それはある
# [00:02:55,900 --> 00:02:56,900] でもギュッとじゃなくて
# [00:02:56,900 --> 00:02:57,900] うん、こうじゃないの
# [00:02:57,900 --> 00:02:59,900] なんかこうやって座ってて
# [00:02:59,900 --> 00:03:01,900] なんかね、角度をこうやってやったら
# [00:03:01,900 --> 00:03:02,900] こんなになったって
# [00:03:02,900 --> 00:03:06,350] マセヤケツとか言ってこうやってやってたよ
# [00:03:06,350 --> 00:03:07,350] そんなこと言ってんすか
# [00:03:07,350 --> 00:03:08,350] やってたやつだよ
# [00:03:08,350 --> 00:03:10,350] えーちょっと怖いっすねそれ
# [00:03:10,350 --> 00:03:11,350] マジっすか
# [00:03:11,350 --> 00:03:14,350] 話知らんふりして聞いてたもん
# [00:03:14,350 --> 00:03:18,700] えーなんか、でもなんか
# [00:03:18,700 --> 00:03:20,700] だってもう、だって何年?
# [00:03:20,700 --> 00:03:21,700] 入社して何年だ?
# [00:03:21,700 --> 00:03:22,700] いや、もう結構
# [00:03:22,700 --> 00:03:24,740] 誕生、4年
# [00:03:24,740 --> 00:03:25,740] だよね?
# [00:03:25,740 --> 00:03:28,500] うん、言ってたよ
# [00:03:28,500 --> 00:03:30,860] え、でもなんか
# [00:03:30,860 --> 00:03:31,860] なんか、でも
# [00:03:31,860 --> 00:03:33,860] チョコとかもらったことないっすよ
# [00:03:33,860 --> 00:03:35,920] あの、あのおばちゃんは
# [00:03:35,920 --> 00:03:36,920] 受付の子とか
# [00:03:36,920 --> 00:03:38,920] あともう一人さ
# [00:03:38,920 --> 00:03:39,920] あの、総務の方もさ
# [00:03:39,920 --> 00:03:40,920] とか狙ってんだけど
# [00:03:40,920 --> 00:03:42,920] あのおばちゃん怖いから
# [00:03:42,920 --> 00:03:43,920] 手出せない
# [00:03:43,920 --> 00:03:46,430] 社内結構無理よ
# [00:03:46,430 --> 00:03:47,430] いや
# [00:03:47,430 --> 00:03:48,430] 残念
# [00:03:48,430 --> 00:03:50,070] もうね、社外
# [00:03:50,070 --> 00:03:52,580] 社外に行くしかない
# [00:03:52,580 --> 00:03:55,260] 結構モテてる
# [00:03:55,260 --> 00:03:56,260] マジっすか
# [00:03:56,260 --> 00:03:57,260] マセヤケツ
# [00:03:57,260 --> 00:03:59,900] 大丈夫、絶対
# [00:03:59,900 --> 00:04:01,900] 明日から態度出してない
# [00:04:01,900 --> 00:04:03,900] いや、でもちょっと怖いな
# [00:04:03,900 --> 00:04:04,900] ん?
# [00:04:04,900 --> 00:04:05,900] なんで怖いの?
# [00:04:05,900 --> 00:04:07,900] 女人に襲われるの怖いの?
# [00:04:07,900 --> 00:04:08,900] いやいや、なんじゃなくてよ
# [00:04:08,900 --> 00:04:09,900] なんか
# [00:04:09,900 --> 00:04:12,730] いや、なんか
# [00:04:12,730 --> 00:04:14,730] 平常心でいられないような気がする
# [00:04:14,730 --> 00:04:15,730] なんか、あんまり
# [00:04:15,730 --> 00:04:17,730] いいじゃん、モテを
# [00:04:17,730 --> 00:04:19,730] いや、まあ
# [00:04:19,730 --> 00:04:22,420] え、な、え?
# [00:04:22,420 --> 00:04:23,420] 先週のみ行ったじゃん
# [00:04:23,420 --> 00:04:24,420] はい
# [00:04:24,420 --> 00:04:25,780] え?
# [00:04:25,780 --> 00:04:26,780] その前も行ったじゃん
# [00:04:26,780 --> 00:04:27,780] はい
# [00:04:27,780 --> 00:04:28,780] その時も
# [00:04:28,780 --> 00:04:29,780] 別に出ようっつったじゃん
# [00:04:29,780 --> 00:04:30,780] 会社から
# [00:04:30,780 --> 00:04:31,780] ああ、はい
# [00:04:31,780 --> 00:04:32,780] あれ、なんでかっつったら
# [00:04:32,780 --> 00:04:33,780] 経理のおばちゃんが
# [00:04:33,780 --> 00:04:35,640] 睨んでるから
# [00:04:35,640 --> 00:04:38,220] 私が領収切れないから
# [00:04:38,220 --> 00:04:39,220] 営業で
# [00:04:39,220 --> 00:04:40,220] いや、でもやっぱり
# [00:04:40,220 --> 00:04:41,220] あれ、全部落としてるもん
# [00:04:41,220 --> 00:04:43,220] え、大丈夫なんすか?バレないっす?
# [00:04:43,220 --> 00:04:45,280] うん、営業だもん、私
# [00:04:45,280 --> 00:04:46,280] 強いよ
# [00:04:46,280 --> 00:04:47,280] マジっすか
# [00:04:47,280 --> 00:04:48,280] 領収切れるもん、すぐ
# [00:04:48,280 --> 00:04:49,340] 接待費で
# [00:04:49,340 --> 00:04:51,340] いやー、でも俺全然
# [00:04:51,340 --> 00:04:52,340] なんかそういうのあんまり
# [00:04:52,340 --> 00:04:54,860] なんか、まあ先輩とかやってるかもしれないけど
# [00:04:54,860 --> 00:04:57,020] なんかそういうこと
# [00:04:57,020 --> 00:04:58,020] 教わってなくて
# [00:04:58,020 --> 00:05:00,020] 私だって毎回領収切ってんじゃん
# [00:05:00,020 --> 00:05:01,180] え、あれ
# [00:05:01,180 --> 00:05:03,180] やばくないっすか?大丈夫です?
# [00:05:03,180 --> 00:05:04,180] 分かんない
# [00:05:04,180 --> 00:05:05,880] だってそんだけ立てたし
# [00:05:05,880 --> 00:05:08,300] ちゃんと数字上げてるもん
# [00:05:08,300 --> 00:05:10,300] ああ、まあ確かに
# [00:05:10,300 --> 00:05:12,300] 今日もだって切ってきちゃった
# [00:05:12,300 --> 00:05:13,840] え、結構今日
# [00:05:13,840 --> 00:05:15,840] 結構飲んだんじゃないっすか、今日
# [00:05:15,840 --> 00:05:17,840] え、でもワイン一本と
# [00:05:17,840 --> 00:05:19,900] シャンパン
# [00:05:19,900 --> 00:05:21,000] まあ、グラシアンだったでしょ
# [00:05:21,000 --> 00:05:23,060] いやいや、食い物も結構
# [00:05:23,060 --> 00:05:24,060] 私食べてないよ、私
# [00:05:24,060 --> 00:05:26,060] 食べないもん、今日もあんまり
# [00:05:26,060 --> 00:05:27,320] まあ、食べてたけど
# [00:05:27,320 --> 00:05:28,320] ああ、そうか、あんま食ってなかった
# [00:05:28,320 --> 00:05:29,320] もう、出しておらない
# [00:05:29,320 --> 00:05:30,380] うん
# [00:05:30,380 --> 00:05:31,380] え、それもちゃんと
# [00:05:31,380 --> 00:05:33,380] 二人で接待費で落としてる
# [00:05:33,380 --> 00:05:34,540] マジっすか
# [00:05:34,540 --> 00:05:35,540] うん
# [00:05:35,540 --> 00:05:36,540] やべー、じゃあ共犯じゃないっすか
# [00:05:36,540 --> 00:05:38,540] だからほら、終電なくしたからさ
# [00:05:38,540 --> 00:05:39,540] 得し
# [00:05:39,540 --> 00:05:40,960] え、得ないもん?
# [00:05:40,960 --> 00:05:41,960] あ、でも
# [00:05:41,960 --> 00:05:42,960] あ、全部落ちるだろよ
# [00:05:42,960 --> 00:05:43,960] 当たり前じゃん
# [00:05:43,960 --> 00:05:46,370] マジっすか
# [00:05:46,370 --> 00:05:47,370] うん
# [00:05:47,370 --> 00:05:48,370] すごい
# [00:05:48,370 --> 00:05:49,370] 勉強になります
# [00:05:50,370 --> 00:05:51,910] よし
# [00:05:51,910 --> 00:05:52,910] よし、じゃあ今日はもう
# [00:05:52,910 --> 00:05:54,940] ここはお泊りだね
# [00:05:54,940 --> 00:05:55,940] 残念ながら
# [00:05:55,940 --> 00:05:57,070] いや、まあ
# [00:05:57,070 --> 00:05:59,070] 残念ではないんですけど
# [00:05:59,070 --> 00:06:00,070] ここはあれですよね
# [00:06:00,070 --> 00:06:01,900] なんか
# [00:06:01,900 --> 00:06:02,900] あれ、寝室ですよね
# [00:06:02,900 --> 00:06:03,900] うん
# [00:06:03,900 --> 00:06:04,900] でも毎日足リネンは
# [00:06:04,900 --> 00:06:05,900] こういうのをね
# [00:06:05,900 --> 00:06:06,900] リネンって言うんだけど
# [00:06:06,900 --> 00:06:08,900] 毎日ちゃんと掃除してるから
# [00:06:08,900 --> 00:06:09,900] いやいや、でも
# [00:06:09,900 --> 00:06:11,030] うん
# [00:06:11,030 --> 00:06:12,030] でも、まあ
# [00:06:12,030 --> 00:06:15,980] 豚野さんは
# [00:06:15,980 --> 00:06:16,980] 帰ってくるわけないじゃん
# [00:06:16,980 --> 00:06:17,980] やめないじゃん
# [00:06:17,980 --> 00:06:18,980] いや、まあそうですけど
# [00:06:18,980 --> 00:06:19,980] なんかでも
# [00:06:19,980 --> 00:06:20,980] ちょっと怖いじゃないっすか
# [00:06:20,980 --> 00:06:21,980] いや、出張中
# [00:06:21,980 --> 00:06:24,170] あのー
# [00:06:24,170 --> 00:06:25,170] セット受けてるから
# [00:06:25,170 --> 00:06:26,170] 間違いなく
# [00:06:26,170 --> 00:06:27,170] あのー
# [00:06:27,170 --> 00:06:30,940] ここら辺半径
# [00:06:30,940 --> 00:06:31,940] 10キロ以上いない
# [00:06:31,940 --> 00:06:33,190] 20キロかな
# [00:06:33,190 --> 00:06:34,190] いや
# [00:06:34,190 --> 00:06:35,190] いや、30キロかな
# [00:06:35,190 --> 00:06:36,190] いや、でも
# [00:06:36,190 --> 00:06:37,190] いないいない
# [00:06:37,190 --> 00:06:38,190] わかんないじゃないっすか
# [00:06:38,190 --> 00:06:39,190] これなんか最近
# [00:06:39,190 --> 00:06:40,190] なんか芸能人で
# [00:06:40,190 --> 00:06:41,190] なんか結構問題になった人
# [00:06:41,190 --> 00:06:42,190] いたいじゃないっすか
# [00:06:42,190 --> 00:06:43,190] 知らないよ、そんなの
# [00:06:43,190 --> 00:06:44,190] うちは別だから
# [00:06:44,190 --> 00:06:45,190] あのー
# [00:06:45,190 --> 00:06:46,190] いや、結構あれ
# [00:06:46,190 --> 00:06:47,190] すげー話題になったんっすよ
# [00:06:47,190 --> 00:06:48,190] ニュースとかでも
# [00:06:48,190 --> 00:06:49,190] 私芸能人じゃないし
# [00:06:49,190 --> 00:06:50,190] いやいや、でも
# [00:06:50,190 --> 00:06:51,190] 会社員だから
# [00:06:51,190 --> 00:06:52,190] いやいや、ちょっと違いますね
# [00:06:52,190 --> 00:06:53,190] なんかそういう状況が
# [00:06:53,190 --> 00:06:54,190] もしかしたら
# [00:06:54,190 --> 00:06:55,510] ちょっと
# [00:06:55,510 --> 00:06:57,510] 起こるかなーなって思ったら
# [00:06:57,510 --> 00:06:58,510] ちょっとやばいじゃないっすか
# [00:06:58,510 --> 00:06:59,510] いや、ないないない
# [00:06:59,510 --> 00:07:00,510] ありえない
# [00:07:00,510 --> 00:07:03,220] だってもうここの接待先を
# [00:07:03,220 --> 00:07:04,220] 知ってるもんだし、全部
# [00:07:04,220 --> 00:07:07,660] だから絶対帰ってこない
# [00:07:07,660 --> 00:07:08,660] 帰ってくるわけないじゃん
# [00:07:08,660 --> 00:07:11,870] 帰ってきてたら今頃いるよ
# [00:07:11,870 --> 00:07:12,870] 家に
# [00:07:12,870 --> 00:07:13,870] まあまあ
# [00:07:13,870 --> 00:07:15,870] そういうことそういうこと
# [00:07:15,870 --> 00:07:24,550] いや、家だしいいじゃん
# [00:07:24,550 --> 00:07:25,550] ダメ?
# [00:07:25,550 --> 00:07:26,550] いやいや、ダメくないっす
# [00:07:26,550 --> 00:07:27,550] ダメくないっす
# [00:07:27,550 --> 00:07:28,550] うちだしいいじゃん
# [00:07:28,550 --> 00:07:32,140] いや、いいよ
# [00:07:32,140 --> 00:07:33,140] ゆっくりしてて
# [00:07:33,140 --> 00:07:34,140] なんでさ
# [00:07:34,140 --> 00:07:35,140] 脱いでいいよ
# [00:07:35,140 --> 00:07:36,140] え?
# [00:07:36,140 --> 00:07:37,140] 何で?
# [00:07:37,140 --> 00:07:38,140] いやいやいや
# [00:07:38,140 --> 00:07:39,140] 脱いでんの?
# [00:07:39,140 --> 00:07:40,140] いやいやいや
# [00:07:40,140 --> 00:07:41,140] 脱げないの?
# [00:07:41,140 --> 00:07:42,880] いや、まあ
# [00:07:42,880 --> 00:07:43,880] ほら
# [00:07:43,880 --> 00:07:44,880] ほら、バリバリいる
# [00:07:44,880 --> 00:07:48,340] 静電気が
# [00:07:48,340 --> 00:07:49,340] 静電気すごいね
# [00:07:49,340 --> 00:08:01,580] 大丈夫だよ
# [00:08:01,580 --> 00:08:02,580] 何?何?何?
# [00:08:02,580 --> 00:08:03,580] いやいや
# [00:08:03,580 --> 00:08:04,580] 下も
# [00:08:04,580 --> 00:08:05,580] シワになったらね
# [00:08:05,580 --> 00:08:07,470] いやいや、あの
# [00:08:07,470 --> 00:08:17,850] 汚いじゃん
# [00:08:17,850 --> 00:08:18,850] いや、あの
# [00:08:18,850 --> 00:08:19,980] 怒られるんだね
# [00:08:19,980 --> 00:08:20,980] 赤羽ちゃんに
# [00:08:20,980 --> 00:08:23,640] いやいや
# [00:08:23,640 --> 00:08:28,220] なんか
# [00:08:28,220 --> 00:08:29,220] 毎日が
# [00:08:29,220 --> 00:08:30,220] 勇み足なんだ
# [00:08:30,220 --> 00:08:31,540] いや
# [00:08:31,540 --> 00:08:32,540] まあ、あの
# [00:08:32,540 --> 00:08:34,540] た、たまになんていうんですかね
# [00:08:34,540 --> 00:08:35,540] ん?
# [00:08:35,540 --> 00:08:42,940] 焼かないんですよ、僕は
# [00:08:42,940 --> 00:08:43,940] たまに焼かないの?
# [00:08:43,940 --> 00:08:44,940] あ、いつも履いてんの?
# [00:08:44,940 --> 00:08:45,940] いや、いつもは履いてますけど
# [00:08:45,940 --> 00:08:46,940] んー
# [00:08:46,940 --> 00:08:50,600] なんか
# [00:08:50,600 --> 00:08:54,190] 乳してる時とか
# [00:08:54,190 --> 00:08:56,190] 年がら年中大変ね、男だもん
# [00:08:56,190 --> 00:08:58,890] え、でもなんか
# [00:08:58,890 --> 00:08:59,890] ん?
# [00:08:59,890 --> 00:09:01,240] ブラとかしない時とかって
# [00:09:01,240 --> 00:09:02,240] なくないですか?
# [00:09:02,240 --> 00:09:03,240] 私?
# [00:09:03,240 --> 00:09:04,240] うん
# [00:09:04,240 --> 00:09:05,500] あー、いや、ないかな
# [00:09:05,500 --> 00:09:06,560] 仕事の時はちゃんとしてるよ
# [00:09:06,560 --> 00:09:07,560] あー
# [00:09:07,560 --> 00:09:08,560] 普段はあんましないけど
# [00:09:08,560 --> 00:09:09,560] うん
# [00:09:09,560 --> 00:09:14,690] いや、ないの?
# [00:09:14,690 --> 00:09:15,690] いや
# [00:09:15,690 --> 00:09:16,690] あります
# [00:09:16,690 --> 00:09:17,690] いい感じに酒飲んだし
# [00:09:17,690 --> 00:09:18,690] そうですね
# [00:09:18,690 --> 00:09:19,690] うん
# [00:09:19,690 --> 00:09:20,940] でも脱ぎないよ
# [00:09:20,940 --> 00:09:21,940] いいよ、見ないからそんなに
# [00:09:21,940 --> 00:09:22,940] なんですか?
# [00:09:22,940 --> 00:09:27,340] 何ドキドキしてるの
# [00:09:27,340 --> 00:09:28,340] いやいや
# [00:09:28,340 --> 00:09:29,340] 大丈夫だって
# [00:09:29,340 --> 00:09:34,050] いや、いや、はい
# [00:09:34,050 --> 00:09:36,050] でも、昨日からマジにいくつも分かっててさ
# [00:09:36,050 --> 00:09:37,050] うん
# [00:09:37,050 --> 00:09:38,050] よくノーファンでさ、来たね
# [00:09:38,050 --> 00:09:39,050] 今日
# [00:09:39,050 --> 00:09:40,050] いやいや
# [00:09:40,050 --> 00:09:41,050] やる気だね
# [00:09:41,050 --> 00:09:42,050] いやいや、そ、そんなんじゃないですけど
# [00:09:42,050 --> 00:09:43,050] やる気だろ?
# [00:09:43,050 --> 00:09:44,590] やる気だ
# [00:09:44,590 --> 00:09:45,590] 脱いでもらうよ
# [00:09:45,590 --> 00:09:47,590] これ、そう、そうかとはね
# [00:09:47,590 --> 00:09:48,590] リベルトとかで寝ますよ、俺
# [00:09:48,590 --> 00:09:49,590] いいじゃん
# [00:09:49,590 --> 00:09:50,590] 一緒に寝よう
# [00:09:50,590 --> 00:09:51,590] ダメなの?
# [00:09:51,590 --> 00:09:52,780] いや
# [00:09:52,780 --> 00:09:53,780] いや、ダメじゃないですけど
# [00:10:06,880 --> 00:10:07,880] いや、ちょっと待ってくださいよ
# [00:10:07,880 --> 00:10:08,880] 恥ずかしい
# [00:10:08,880 --> 00:10:09,880] いい理由
# [00:10:09,880 --> 00:10:10,880] 何かあるからね
# [00:10:10,880 --> 00:10:11,880] あ、あ、あ
# [00:10:11,880 --> 00:10:12,880] はーい、募集
# [00:10:12,880 --> 00:10:19,480] え
# [00:10:19,480 --> 00:10:22,530] え、なんで?
# [00:10:22,530 --> 00:10:26,130] ちょっと、ちゃんとしようにならないように置いといてあげるから
# [00:10:26,130 --> 00:10:27,640] 何やってんの?
# [00:10:27,640 --> 00:10:28,640] ちょっとちゃんと見せてよ
# [00:10:28,640 --> 00:10:29,640] え、いや何ですか?
# [00:10:29,640 --> 00:10:30,640] いいじゃん、見せてよ
# [00:10:30,640 --> 00:10:31,640] いや
# [00:10:31,640 --> 00:10:32,640] いいじゃん、私を見せてんだからいいじゃん
# [00:10:32,640 --> 00:10:33,640] いやいやいや、はあ
# [00:10:33,640 --> 00:10:38,530] いや、ちょっとエリカさん恥ずかしいです
# [00:10:38,530 --> 00:10:40,530] 若い体は見たいから
# [00:10:40,530 --> 00:10:41,530] いや、いや
# [00:10:41,530 --> 00:10:47,100] もうちょい、ちょい、ちょい
# [00:10:47,100 --> 00:10:48,100] はい、ちょっと
# [00:10:48,100 --> 00:10:52,400] 酔っ払って駄目
# [00:10:52,400 --> 00:10:53,400] いや、いや、大丈夫です、大丈夫です
# [00:10:53,400 --> 00:10:54,400] いいよ、いいよ、はい、ここに
# [00:10:54,400 --> 00:10:55,400] 酔っ払っていいよ
# [00:10:56,400 --> 00:10:57,750] また嫌いで見ちゃった
# [00:10:57,750 --> 00:10:58,750] いや
# [00:10:58,750 --> 00:11:01,420] ちょっ
# [00:11:01,420 --> 00:11:03,420] めっちゃくちゃセクハラじゃないですか
# [00:11:03,420 --> 00:11:06,180] 違うよ
# [00:11:06,180 --> 00:11:08,180] だって自ら家に来たんでしょ
# [00:11:08,180 --> 00:11:10,310] セクハラじゃないよ
# [00:11:10,310 --> 00:11:12,630] ノーパンで来たんでしょ
# [00:11:12,630 --> 00:11:15,080] 嫌ならやめる?
# [00:11:15,080 --> 00:11:17,080] 嫌じゃないんですけど
# [00:11:17,080 --> 00:11:19,240] 嫌な割には
# [00:11:19,240 --> 00:11:21,240] 元気になってるんだけど
# [00:11:21,240 --> 00:11:23,240] 酔ってる割に
# [00:11:23,240 --> 00:11:26,390] 嫌な割には
# [00:11:26,390 --> 00:11:28,390] 立ってるんだけど
# [00:11:28,390 --> 00:11:30,520] よーく見せてよ
# [00:11:30,520 --> 00:11:42,540] 家に行っていいね
# [00:11:42,540 --> 00:11:46,810] よーく見せてよ
# [00:11:46,810 --> 00:11:54,280] 何震えたんの?
# [00:11:54,280 --> 00:11:56,340] 怖いの?
# [00:11:56,340 --> 00:11:58,730] 怖いんだったらやめるけど
# [00:11:58,730 --> 00:12:06,300] やめるけど?
# [00:12:06,300 --> 00:12:08,620] そんな顔するんだ
# [00:12:08,620 --> 00:12:10,620] 嫌なの?
# [00:12:10,620 --> 00:12:12,620] 嫌ならやめるよ
# [00:12:12,620 --> 00:12:15,190] いいよ
# [00:12:15,190 --> 00:12:19,180] でもこんななってるんだけど
# [00:12:19,180 --> 00:12:22,460] 自分で我慢できる?
# [00:12:22,460 --> 00:12:27,240] それとも自分でオーナーにする?
# [00:12:27,240 --> 00:12:29,500] どっちがいい?
# [00:12:29,500 --> 00:12:34,440] 最初からすぐやばいのね
# [00:12:34,440 --> 00:12:36,440] 最初からすぐやばいのね
# [00:12:36,440 --> 00:12:40,780] あーやだ
# [00:12:40,780 --> 00:12:43,260] すごい大きい
# [00:12:43,260 --> 00:12:45,260] マサヤすごいね
# [00:12:45,260 --> 00:12:53,140] 大きい
# [00:12:53,140 --> 00:12:55,140] 比べたらあれだけどうちのよりはすごいわ
# [00:12:55,140 --> 00:12:57,140] 100倍ぐらい
# [00:12:57,140 --> 00:13:01,160] 若さかな
# [00:13:01,160 --> 00:13:03,160] 若さっていいね
# [00:13:03,160 --> 00:13:05,160] どこどこ言ってる
# [00:13:05,160 --> 00:13:22,040] 恥ずかしいね
# [00:13:25,000 --> 00:13:28,890] どこが気持ちいいの?
# [00:13:28,890 --> 00:13:33,700] ここ?
# [00:13:33,700 --> 00:13:35,700] それとも先?
# [00:13:35,700 --> 00:13:38,410] それとも裏?
# [00:13:38,410 --> 00:14:31,350] どうしたの?
# [00:14:31,350 --> 00:14:42,020] そんな
# [00:14:42,020 --> 00:14:45,240] もっとやってほしいよ
# [00:14:45,240 --> 00:14:47,750] 嫌ならやめるけど
# [00:14:47,750 --> 00:14:49,750] いや行為じゃないとだって
# [00:14:49,750 --> 00:14:51,780] 後で何言われたら困るしね
# [00:14:51,780 --> 00:14:54,620] どうなの?
# [00:14:54,620 --> 00:15:01,700] ん?
# [00:15:01,700 --> 00:15:11,990] 大きな声で聞こえない
# [00:15:11,990 --> 00:15:26,630] もっと大きな声で言って
# [00:15:26,630 --> 00:15:38,300] あなた正直ね
# [00:15:38,300 --> 00:16:11,210] 我慢できんのね
# [00:16:11,210 --> 00:16:20,980] すごい太い
# [00:16:20,980 --> 00:16:22,980] エリカって呼んで
# [00:16:22,980 --> 00:16:30,260] 私もマサヤって呼ぶから
# [00:16:30,260 --> 00:16:35,660] 言えない
# [00:16:35,660 --> 00:16:40,600] これからはエリカって呼んでね
# [00:16:40,600 --> 00:16:43,850] 会社の外では
# [00:16:43,850 --> 00:16:57,050] うん
# [00:16:57,050 --> 00:17:10,280] たまたまがいいの?
# [00:17:10,280 --> 00:17:20,790] うん
# [00:17:20,790 --> 00:17:30,380] 露天じゃないでしょ
# [00:17:30,380 --> 00:17:35,000] いや
# [00:17:35,000 --> 00:17:37,000] エリカって呼んで
# [00:17:37,000 --> 00:17:40,630] 酸なんかつけないで
# [00:17:40,630 --> 00:17:46,090] 餃子めする
# [00:17:46,090 --> 00:17:49,850] 噛んじゃうよ
# [00:17:49,850 --> 00:18:05,220] じゃあエリカって呼んで
# [00:18:05,220 --> 00:18:09,270] 噛んじゃうよ
# [00:18:09,270 --> 00:18:24,970] ダメならエリカって呼んで
# [00:18:24,970 --> 00:18:28,090] なに?
# [00:18:28,090 --> 00:18:54,920] 気持ちいいでしょ?
# [00:18:54,920 --> 00:18:56,920] 恥ずかしいな
# [00:18:56,920 --> 00:19:02,440] 何恥ずかしいの?
# [00:19:02,440 --> 00:19:06,390] 恥ずかしいよみんなは正直
# [00:19:06,390 --> 00:19:15,430] 今こんななっちゃったし
# [00:19:15,430 --> 00:19:19,420] 若いからだって最高
# [00:19:19,420 --> 00:19:24,100] しかもみんなが狙ってる
# [00:19:24,100 --> 00:19:28,060] そんな若い男を
# [00:19:28,060 --> 00:19:30,060] 怖いって
# [00:19:30,060 --> 00:19:34,010] 遊べるのだから
# [00:19:34,010 --> 00:19:38,020] ん?
# [00:19:38,020 --> 00:19:40,020] リラックスして
# [00:19:40,020 --> 00:19:44,100] 気持ちよくなればいいし
# [00:19:44,100 --> 00:19:55,700] ん?
# [00:19:55,700 --> 00:19:58,250] なに?
# [00:19:58,250 --> 00:20:09,850] なに?
# [00:20:09,850 --> 00:20:11,850] はっきりしないと
# [00:20:11,850 --> 00:20:13,850] いつまでもぼっちゃまつかいよ
# [00:20:13,850 --> 00:20:16,360] 会社でいいの?そんなんで
# [00:20:16,360 --> 00:20:50,680] はっきり言ってごらん
# [00:20:50,680 --> 00:20:53,930] どうやって飲みたいの?
# [00:20:53,930 --> 00:21:37,300] めちゃくちゃエロいんじゃん
# [00:21:37,300 --> 00:23:40,650] 好きなの?
# [00:23:40,650 --> 00:23:57,210] こんなこともある?
# [00:23:57,210 --> 00:24:01,190] まずいでしょ
# [00:24:01,190 --> 00:24:04,700] 旅さんに入るのが
# [00:24:04,700 --> 00:24:07,590] こんな気の位置
# [00:24:07,590 --> 00:24:13,910] 嬉しい
# [00:24:13,910 --> 00:34:45,540] すっごい
# [00:34:45,540 --> 00:46:40,250] いっぱい出たね
# [00:46:40,250 --> 00:47:19,590] 今度飲ませなさいよ
# [00:47:19,590 --> 00:47:27,860] 来週やな
# [00:47:27,860 --> 00:48:05,510] 何家に戻ってんのよ
# [00:48:05,510 --> 00:48:57,590] 一緒に行った?
# [00:48:57,590 --> 00:49:11,980] 大丈夫
# [00:49:11,980 --> 00:49:15,800] 目痛い
# [00:49:15,800 --> 00:50:23,620] チョコレート選んで
# [00:50:23,620 --> 00:50:25,620] いいよ
# [00:50:25,620 --> 00:50:32,010] いいいい
# [00:50:32,010 --> 00:50:35,160] 綺麗にした?
# [00:50:35,160 --> 00:50:37,160] うん
# [00:50:37,160 --> 00:50:39,860] 入る?
# [00:50:39,860 --> 00:50:42,090] まだ入れない?
# [00:50:42,090 --> 00:50:55,990] まだ入れない
# [00:50:55,990 --> 00:51:00,100] 温度調節して
# [00:51:00,100 --> 00:51:02,230] すげーおやつ
# [00:51:02,230 --> 00:51:49,480] 気づきました
# [00:51:49,480 --> 00:52:48,020] 綺麗な顔が
# [00:52:48,020 --> 00:54:45,930] やったばっかりに
# [00:54:45,930 --> 00:54:48,660] やべーじゃん
# [00:54:48,660 --> 01:07:28,680] 顔ショックして
# [01:07:28,680 --> 01:07:53,240] いい
# [01:07:53,240 --> 01:07:56,460] 寝てもいい?
# [01:07:56,460 --> 01:08:02,520] 寝ちゃうかもしれない
# [01:08:02,520 --> 01:08:04,520] いいよ寝てても
# [01:08:04,520 --> 01:08:07,830] よだれ垂らしてもいいよ
# [01:08:07,830 --> 01:08:09,830] こっちに置いておいて
# [01:08:09,830 --> 01:08:21,020] すごいね
# [01:08:21,020 --> 01:08:25,220] 何かやってたの?
# [01:08:25,220 --> 01:08:28,500] 昔ね部活でね
# [01:08:28,500 --> 01:08:30,500] 先輩がさせられてたから
# [01:08:30,500 --> 01:08:32,500] 俺も部活前やっててさ
# [01:08:32,500 --> 01:08:35,110] よくさせられてた
# [01:08:35,110 --> 01:08:37,140] でもさ
# [01:08:37,140 --> 01:08:40,300] 全然場合が違う
# [01:08:40,300 --> 01:08:42,300] 本格的じゃん
# [01:08:42,300 --> 01:08:44,300] だってうるさかったもん
# [01:08:44,300 --> 01:08:46,460] 厳しかったし
# [01:08:46,460 --> 01:08:58,660] 張ってる人すぐ張っちゃう
# [01:08:58,660 --> 01:09:08,220] なんだこの人
# [01:09:08,220 --> 01:09:23,500] ゴリゴリ言ってる
# [01:09:23,500 --> 01:09:35,580] 一人休んでた
# [01:09:35,580 --> 01:09:38,280] そうだったの?
# [01:09:38,280 --> 01:09:42,040] 左背にもね
# [01:09:42,040 --> 01:09:44,900] ゴリゴリくら
# [01:09:44,900 --> 01:09:54,650] これねすごいね
# [01:09:54,650 --> 01:09:57,290] 起こしてあげるって大丈夫よ
# [01:09:57,290 --> 01:09:59,320] もっと寝たほうが
# [01:09:59,320 --> 01:10:01,450] 今日は
# [01:10:01,450 --> 01:10:03,670] 今日も出張中です
# [01:10:03,670 --> 01:10:05,930] マジか結構多いね
# [01:10:05,930 --> 01:10:07,930] えー
# [01:10:07,930 --> 01:10:09,930] ずーっと出張行ってくれてないのにね
# [01:10:09,930 --> 01:10:12,120] それはでしょ
# [01:10:12,120 --> 01:10:14,120] だめ?
# [01:10:14,120 --> 01:10:16,120] できれば年に何回かで
# [01:10:16,120 --> 01:10:18,120] いいよ帰ってくるの
# [01:10:18,120 --> 01:10:22,550] 気持ちいいよ
# [01:10:22,550 --> 01:10:35,980] そんなに
# [01:10:35,980 --> 01:10:38,460] 出張が多いっておかしいと思う?
# [01:10:38,460 --> 01:10:41,700] 忙しいんだからね
# [01:10:41,700 --> 01:10:43,700] うん忙しいからいいんだよ
# [01:10:43,700 --> 01:10:46,310] それ
# [01:10:46,310 --> 01:10:48,920] いやもう
# [01:10:48,920 --> 01:10:53,480] 仕事じゃないから行けよ
# [01:10:53,480 --> 01:10:55,480] すごくうらやましい
# [01:10:55,480 --> 01:10:58,730] うらやましい?
# [01:10:58,730 --> 01:11:00,730] こっちはたまったもんじゃないよ
# [01:11:00,730 --> 01:11:02,730] 洗濯物いきなりドーンって持ってくる
# [01:11:02,730 --> 01:11:04,790] そういうことか
# [01:11:04,790 --> 01:11:06,790] そうだそうだ
# [01:11:06,790 --> 01:11:08,790] 行くなら永遠に行っててほしい
# [01:11:08,790 --> 01:11:10,980] ははは
# [01:11:10,980 --> 01:11:14,140] だからあれだ
# [01:11:14,140 --> 01:11:16,140] 出張先とかで
# [01:11:16,140 --> 01:11:18,140] 全然洗濯しない人なんだって
# [01:11:18,140 --> 01:11:20,230] そうだね
# [01:11:20,230 --> 01:11:22,460] そうだね
# [01:11:22,460 --> 01:11:24,710] 洗濯でいいか
# [01:11:24,710 --> 01:11:26,710] いやホテルでできるんだけど
# [01:11:26,710 --> 01:11:29,510] なんか下着とかは恥ずかしいらしいよ
# [01:11:29,510 --> 01:11:31,510] やればいいのに別に女の子じゃないから
# [01:11:31,510 --> 01:11:38,630] すごい
# [01:11:38,630 --> 01:11:40,630] ちょっとこれ邪魔ね
# [01:11:40,630 --> 01:11:42,630] すっぽっぽになっちゃう
# [01:11:42,630 --> 01:11:44,630] 寝る前に
# [01:11:44,630 --> 01:11:47,140] 寝たらぐる寝ないじゃん
# [01:11:47,140 --> 01:11:50,420] よいしょ
# [01:11:50,420 --> 01:11:54,420] よだれてたらいけないからこれ犠牲にしよう
# [01:11:54,420 --> 01:11:57,190] いくら払っていい?
# [01:11:57,190 --> 01:11:59,190] これをここに置いておく
# [01:11:59,190 --> 01:12:03,850] いくらいくらこれ
# [01:12:03,850 --> 01:12:05,850] 何が?
# [01:12:05,850 --> 01:12:08,010] 高いよ
# [01:12:08,010 --> 01:12:10,200] ははは
# [01:12:10,200 --> 01:12:12,200] まさやの
# [01:12:12,200 --> 01:12:14,200] 体で払ってもらうから大丈夫
# [01:12:14,200 --> 01:12:16,200] ははは
# [01:12:16,200 --> 01:12:18,200] 効かなきゃよかった
# [01:12:18,200 --> 01:12:20,200] ねえ効かなきゃよかったね
# [01:12:20,200 --> 01:12:22,200] 痛いね
# [01:12:22,200 --> 01:12:24,200] 痛いよねこれごめん
# [01:12:24,200 --> 01:12:27,830] そうだな
# [01:12:27,830 --> 01:12:30,020] いいよ美肌だから
# [01:12:30,020 --> 01:12:38,140] 美肌だから揺らすよ
# [01:12:38,140 --> 01:12:40,170] ここ気持ちいいでしょ
# [01:12:40,170 --> 01:12:47,480] いいお尻
# [01:12:47,480 --> 01:12:50,120] 叩かれちゃう?
# [01:12:50,120 --> 01:12:52,920] いいお尻
# [01:12:52,920 --> 01:12:56,330] でもお尻埃ってしてたここ
# [01:12:56,330 --> 01:12:58,460] ここ気持ちいい
# [01:12:58,460 --> 01:13:03,460] なんかあるね
# [01:13:03,460 --> 01:13:08,700] あるでしょ
# [01:13:08,700 --> 01:13:13,740] 気持ちいいんだよ
# [01:13:13,740 --> 01:13:15,900] どんどん落としていく
# [01:13:15,900 --> 01:13:17,900] 寝ちゃうねこれね
# [01:13:17,900 --> 01:13:19,900] グッときた
# [01:13:19,900 --> 01:13:21,900] グッときたお尻力入ってるよ
# [01:13:21,900 --> 01:13:27,770] 叩かれてるよ
# [01:13:27,770 --> 01:13:41,060] ザーン
# [01:13:41,060 --> 01:13:43,060] ねえマジマジ見るの久しぶりじゃない?
# [01:13:43,060 --> 01:13:46,700] 私体
# [01:13:46,700 --> 01:13:49,050] 何寝てんの寝ないの
# [01:13:49,050 --> 01:13:51,050] まだ何寝てんの
# [01:13:51,050 --> 01:13:53,050] 寝てない
# [01:13:53,050 --> 01:13:55,110] 寝てない
# [01:13:55,110 --> 01:13:58,680] 今寝落ちしたって言ってた
# [01:13:58,680 --> 01:14:00,680] そう
# [01:14:00,680 --> 01:14:04,540] 私顔なに汗だくで頑張ってるのにさ今
# [01:14:04,540 --> 01:14:16,010] 私脱いは上
# [01:14:16,010 --> 01:14:19,990] 寝てないでしょ完璧に今
# [01:14:19,990 --> 01:14:22,660] 寝ないの
# [01:14:22,660 --> 01:14:26,260] 寝ないの
# [01:14:26,260 --> 01:14:28,260] 寝てたでしょ寝てた
# [01:14:28,260 --> 01:14:30,490] 寝てたよね今ね
# [01:14:30,490 --> 01:14:32,490] 寝てない寝てない
# [01:14:32,490 --> 01:14:37,910] すげえ気持ちいい
# [01:14:37,910 --> 01:14:55,460] 血が回ってるもん
# [01:14:55,460 --> 01:15:01,110] 洗濯屋だし今
# [01:15:01,110 --> 01:15:03,110] 聞いてる?ってね
# [01:15:03,110 --> 01:15:05,110] 聞いてるの人の話
# [01:15:05,110 --> 01:15:07,240] 聞いてる聞いてる
# [01:15:07,240 --> 01:15:09,240] ひどいね
# [01:15:09,240 --> 01:15:11,240] 気持ちいいでしょ
# [01:15:11,240 --> 01:15:13,240] 寝たら叩かれるからね
# [01:15:13,240 --> 01:15:15,240] はい反対
# [01:15:15,240 --> 01:15:17,240] 反対反対反対
# [01:15:17,240 --> 01:15:19,500] こっち向いてこっち向いて
# [01:15:19,500 --> 01:15:21,500] こっち向いてほら
# [01:15:21,500 --> 01:15:23,500] すっぱなかじゃんもう
# [01:15:23,500 --> 01:15:27,000] 寝てさえよ気持ちよくなりたいんでしょ
# [01:15:27,000 --> 01:15:33,540] 気持ちいいでしょ
# [01:15:33,540 --> 01:15:42,260] 余計好きになるでしょ
# [01:15:42,260 --> 01:15:44,260] いいよ
# [01:15:44,260 --> 01:15:46,260] 余計好きになっても
# [01:15:46,260 --> 01:16:01,000] 力抜いて
# [01:16:01,000 --> 01:16:03,000] 店出せってこれ
# [01:16:03,000 --> 01:16:05,000] うっそじゃあ会社辞めようかな
# [01:16:05,000 --> 01:16:09,620] いろんな旅行行ったら
# [01:16:09,620 --> 01:16:11,620] 必ずスパに行くの
# [01:16:11,620 --> 01:16:14,710] こういう
# [01:16:14,710 --> 01:16:16,710] マッサージやってくれるとこ
# [01:16:16,710 --> 01:16:18,710] そこで結構勉強しちゃうんだよね
# [01:16:18,710 --> 01:16:22,950] そういうことか
# [01:16:22,950 --> 01:16:24,950] 気持ちいいでしょ
# [01:16:24,950 --> 01:16:26,950] 右利きだっけ
# [01:16:26,950 --> 01:16:28,950] 教えてもらったりとか
# [01:16:28,950 --> 01:16:31,300] なんか教えてもらったり
# [01:16:31,300 --> 01:16:33,300] こうやってマッサージしてもらいながら
# [01:16:33,300 --> 01:16:41,930] 寝ないで覚えておくの
# [01:16:41,930 --> 01:16:45,720] この状態じゃ寝れないでしょ
# [01:16:45,720 --> 01:16:47,720] 寝ないでしょ寝ないでしょ
# [01:16:47,720 --> 01:16:49,720] 寝ないでしょ
# [01:16:49,720 --> 01:16:51,720] めちゃくちゃ汗かいてんだよ
# [01:16:51,720 --> 01:16:53,720] すっごい汗かいてるでしょ
# [01:16:53,720 --> 01:17:01,640] めっちゃ湿ってんじゃん
# [01:17:05,050 --> 01:17:07,050] そんな恥ずかしい?
# [01:17:07,050 --> 01:17:11,670] じゃあ私も撮ってあげるよ
# [01:17:11,670 --> 01:17:13,670] なんだよ
# [01:17:13,670 --> 01:17:15,670] なんだよ
# [01:17:15,670 --> 01:17:17,670] いいじゃん
# [01:17:17,670 --> 01:17:19,670] たまには明るくないなよ
# [01:17:19,670 --> 01:17:22,860] いつも暗い顔してるんだから
# [01:17:22,860 --> 01:17:24,860] うちに来るときだけじゃん
# [01:17:24,860 --> 01:17:26,860] こんなに明るくない
# [01:17:26,860 --> 01:17:29,620] じゃあこっち向いて
# [01:17:29,620 --> 01:17:31,620] そのままそのまま
# [01:17:31,620 --> 01:17:35,100] そのままそのまま
# [01:17:35,100 --> 01:17:37,100] ちょっと待ってよ
# [01:17:37,100 --> 01:17:39,100] 恥ずかしくないじゃん
# [01:17:39,100 --> 01:17:42,380] 隠れた恥ずかしくないでしょ
# [01:17:42,380 --> 01:17:47,860] 恥ずかしくない
# [01:17:47,860 --> 01:17:53,990] すっごい疲れてるね
# [01:17:53,990 --> 01:17:55,990] 撮っていいこれ
# [01:17:55,990 --> 01:17:58,020] ダメだよ
# [01:17:58,020 --> 01:18:00,020] いいじゃん
# [01:18:00,020 --> 01:18:02,020] たまには明るくならなきゃ
# [01:18:02,020 --> 01:18:04,660] 明るいじゃん
# [01:18:04,660 --> 01:18:09,290] うちではね
# [01:18:09,290 --> 01:18:15,100] うちではね
# [01:18:15,100 --> 01:18:19,910] 気持ちが
# [01:18:19,910 --> 01:18:21,910] 恥ずかしいな
# [01:18:21,910 --> 01:18:23,940] ちょっと待ってよ
# [01:18:23,940 --> 01:18:25,940] ちょっと待って
# [01:18:25,940 --> 01:18:27,940] 写真撮りたいね
# [01:18:27,940 --> 01:18:29,940] ダメ絶対ダメ
# [01:18:29,940 --> 01:18:32,710] ダメ撮れたらしたくない
# [01:18:32,710 --> 01:18:34,710] え?くすぐったんやのね
# [01:18:34,710 --> 01:18:44,620] くすぐった
# [01:18:44,620 --> 01:18:51,290] こんな立ってんじゃん
# [01:18:51,290 --> 01:18:53,350] あーだって
# [01:18:53,350 --> 01:18:55,350] うちに遊びに来たんでしょ
# [01:18:55,350 --> 01:18:58,980] すごい立ってきた
# [01:18:58,980 --> 01:19:01,340] すごい
# [01:19:01,340 --> 01:19:03,590] まだ終わらないわ
# [01:19:03,590 --> 01:19:06,900] まだだよ
# [01:19:06,900 --> 01:19:08,900] これもマッサージで仕事って
# [01:19:08,900 --> 01:19:10,900] 違うマッサージになってんじゃん
# [01:19:10,900 --> 01:19:12,900] なに?
# [01:19:12,900 --> 01:19:15,700] エロいマッサージ?
# [01:19:15,700 --> 01:19:17,700] なんか動いてる
# [01:19:17,700 --> 01:19:19,700] 私のパンツの中で
# [01:19:19,700 --> 01:19:22,380] なんか動いてるよ
# [01:19:22,380 --> 01:19:25,560] 恥ずかしいの?
# [01:19:25,560 --> 01:19:27,820] 恥ずかしいの
# [01:19:27,820 --> 01:19:29,820] すっごい固くなっちゃった
# [01:19:29,820 --> 01:19:32,940] こんななるんだね
# [01:19:32,940 --> 01:19:34,940] いいじゃん
# [01:19:34,940 --> 01:19:36,940] 恥ずかしいんだって
# [01:19:36,940 --> 01:19:40,180] これが恥ずかしい
# [01:19:40,180 --> 01:19:42,180] それがいいじゃん
# [01:19:42,180 --> 01:19:51,060] 恥ずかしいって言いながら
# [01:19:51,060 --> 01:19:58,250] こんななってるよ
# [01:19:58,250 --> 01:20:06,260] あ、いい声が出てきた
# [01:20:06,260 --> 01:20:16,300] マサイもその声大好き
# [01:20:16,300 --> 01:20:18,490] 違う感触ってどうなの?
# [01:20:18,490 --> 01:20:22,660] 私のパンツって
# [01:20:22,660 --> 01:20:24,660] ちょっと悪くない?
# [01:20:24,660 --> 01:20:30,630] あ、そうなんだ
# [01:20:30,630 --> 01:20:35,100] じゃあこっちもそうなのかな
# [01:20:35,100 --> 01:20:37,100] 恥ずかしい
# [01:20:37,100 --> 01:20:49,530] ピンクだピンク
# [01:20:49,530 --> 01:20:51,660] いいよねだって
# [01:20:51,660 --> 01:20:53,660] マッサージ中なんじゃんから
# [01:20:53,660 --> 01:21:17,450] ん?
# [01:21:17,450 --> 01:21:21,850] マッサージどっちが気持ちいいの?
# [01:21:21,850 --> 01:21:26,630] どっちも?
# [01:21:26,630 --> 01:21:35,730] 違うよ
# [01:21:35,730 --> 01:22:31,650] どうしたの?
# [01:22:31,650 --> 01:22:33,650] どうしたの?
# [01:22:33,650 --> 01:22:36,220] 何かミス?
# [01:22:36,220 --> 01:22:41,810] まだね?
# [01:22:41,810 --> 01:22:43,810] まだ
# [01:22:43,810 --> 01:22:47,090] 何か出るの?教えて
# [01:22:47,090 --> 01:22:49,090] もう今日なんか
# [01:22:49,090 --> 01:22:54,450] あ、そうだ
# [01:22:54,450 --> 01:22:59,460] 昨日さ
# [01:22:59,460 --> 01:23:01,460] 買い物してる時にさ
# [01:23:01,460 --> 01:23:03,460] これだったんだって
# [01:23:03,460 --> 01:23:13,940] 買ってきたんだって
# [01:23:13,940 --> 01:23:15,940] 違うやつだ
# [01:23:15,940 --> 01:23:18,130] いつもと違うやつ
# [01:23:18,130 --> 01:23:20,450] ん?何を?
# [01:23:20,450 --> 01:23:23,060] やっぱりちゃんと持って帰ってね
# [01:23:23,060 --> 01:23:25,060] うん
# [01:23:25,060 --> 01:23:28,270] 他でやったらバレるからね
# [01:23:28,270 --> 01:23:30,270] 何が?
# [01:23:30,270 --> 01:23:32,270] 個数が分かるから
# [01:23:32,270 --> 01:23:34,880] 違うやつでしょ
# [01:23:34,880 --> 01:23:36,880] 私の
# [01:23:36,880 --> 01:24:03,420] これどうやってつけるかつけてみて
# [01:24:03,420 --> 01:24:30,610] 入れたいんでしょ?
# [01:24:30,610 --> 01:24:35,040] マッサージどっちが気持ちいい?
# [01:24:35,040 --> 01:24:37,940] どっちもって
# [01:26:09,630 --> 01:29:06,510] ちくみ大好きでしょ?
# [01:29:06,510 --> 01:29:08,510] やっぱり
# [01:29:08,510 --> 01:29:13,070] そのまま寝ちゃうの?
# [01:29:13,070 --> 01:29:25,590] ダメでしょ?
# [01:29:25,590 --> 01:29:31,300] どうなってんの?
# [01:29:31,300 --> 01:29:32,300] 一度座るからさ
# [01:29:32,300 --> 01:29:34,870] そんなにできねえって
# [01:29:34,870 --> 01:29:39,260] 一度座って
# [01:29:39,260 --> 01:29:55,560] 検索分かる?
# [01:29:55,560 --> 01:30:04,110] 気持ちいいよ
# [01:30:04,110 --> 01:30:09,720] もう一回しろよ
# [01:30:09,720 --> 01:30:13,220] どこあんの?
# [01:30:13,220 --> 01:31:04,740] 分かった
# [01:31:04,740 --> 01:31:05,740] 何が分かった?
# [01:31:05,740 --> 01:31:11,000] ねぇ
# [01:31:11,000 --> 01:31:14,060] どうしたの?母って
# [01:31:14,060 --> 01:31:18,010] いや、すげえ早いなと思って俺
# [01:31:18,010 --> 01:31:20,010] 早いなって
# [01:31:20,010 --> 01:31:24,890] いや、今日秒殺されたって
# [01:31:24,890 --> 01:31:27,940] 次も秒殺しちゃおう
# [01:31:27,940 --> 01:31:29,940] ちょっと待って
# [01:31:29,940 --> 01:31:35,780] 引き付けるよね?
# [01:31:35,780 --> 01:31:36,780] じゃあダメ
# [01:31:36,780 --> 01:31:40,020] バレんじゃん、そんなの
# [01:31:40,020 --> 01:31:41,020] 何がバレんの?
# [01:31:41,020 --> 01:31:43,340] よっしゃ
# [01:31:43,340 --> 01:31:45,340] そうじゃそうな私なのに
# [01:31:49,780 --> 01:41:49,850] 激しいけど
# [01:41:49,850 --> 01:42:16,830] 腰が動いてる
# [01:42:20,300 --> 01:52:27,920] 寝ちゃうな
# [01:52:27,920 --> 01:53:06,900] そのままで
# [01:53:06,900 --> 01:53:07,900] どうしてんの?
# **Output file created: /content/drive/My Drive/Colab Notebooks/Faster Whisper/UPLD-002.srt**
